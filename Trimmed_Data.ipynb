# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import variance_inflation_factor
url = "https://raw.githubusercontent.com/erenacid/dtsc-1302-group-17/refs/heads/main/College_Data_17.csv"
df = pd.read_csv(url)
df.head(5)
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
#    PhD  Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0   70        78       18.1           12    7041         60
# 1   29        30       12.2           16   10527         56
# 2   53        66       12.9           30    8735         54
# 3   92        97        7.7           37   19016         59
# 4   76        72       11.9            2   10922         15

# %%
# !git clone https://github.com/erenacid/dtsc-1302-group-17.git
# %cd dtsc-1302-group-17
df = pd.read_csv("College_Data_17.csv")
df['Cost']=df['Outstate']+df['Room.Board']+df["Books"]+df["Personal"]
df['Undergrad']=df['P.Undergrad']+df['F.Undergrad']
df['Enrollment']=df['Enroll']/df['Accept']
df['Acceptance']=df['Accept']/df['Apps']
df= df.drop(['Outstate', 'Room.Board', 'Books', 'Personal', 'Terminal','F.Undergrad','P.Undergrad','Top10perc','Apps','Accept','Enroll'], axis=1)
df.head(5)
# Out:
# Cloning into 'dtsc-1302-group-17'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 15 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (15/15), 2.10 MiB | 6.61 MiB/s, done.
# Resolving deltas: 100% (2/2), done.
# /content/dtsc-1302-group-17/dtsc-1302-group-17/dtsc-1302-group-17/dtsc-1302-group-17/dtsc-1302-group-17/dtsc-1302-group-17/dtsc-1302-group-17/dtsc-1302-group-17
#                      Unnamed: 0 Private  Top25perc  PhD  S.F.Ratio  \
# 0  Abilene Christian University     Yes         52   70       18.1
# 1            Adelphi University     Yes         29   29       12.2
# 2                Adrian College     Yes         50   53       12.9
# 3           Agnes Scott College     Yes         89   92        7.7
# 4     Alaska Pacific University     Yes         44   76       11.9
#
#    perc.alumni  Expend  Grad.Rate   Cost  Undergrad  Enrollment  Acceptance
# 0           12    7041         60  13390       3422    0.585227    0.742169
# 1           16   10527         56  20980       3910    0.266112    0.880146
# 2           30    8735         54  16565       1135    0.306290    0.768207
# 3           37   19016         59  19735        573    0.392550    0.836930
# 4            2   10922         15  13980       1118    0.376712    0.756477

# %%
#Scatterplots
sns.pairplot(df, height=1.5)
plt.show()

# %%
# Correlation Matrix
plt.figure(figsize= (5,3))
numerical_df = df.select_dtypes(include=np.number)

sns.heatmap(numerical_df.corr(), annot=True, cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Correlation Matrix")
plt.show()
